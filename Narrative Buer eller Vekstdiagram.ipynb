# %% [markdown]
# ### Oppstart

# %% [markdown]
# ### Preamble

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, printmd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def plot(urn , wordbag, window=5000, pr=100, lw=3, alpha=0.8):
    md = nb.metadata(urn)[0][1:4]
    #print(md)
    x = nb.plot_book_wordbags(urn , wordbag, window=5000, pr=100)
    x.plot(figsize=(12, 5), lw=lw, alpha=alpha, title=', '.join([str(m) for m in md]))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
update('nbtext', overwrite=True)
import nbtext as nb
import os
from nbtext import vekstdiagram, make_graph, get_urn, relaterte_ord

# %matplotlib inline
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Lokalhistorie\nbtext.py`

# %%
_,_,korpusfiles = next(os.walk('./Analysekorpus'))
bb_korpus = dict()
for f in korpusfiles:
    bb_korpus[f.split('.docx')[0]] = list(set(nb.get_urns_from_docx(os.path.join('./Analysekorpus', f))))
#printmd("""## Delkorpus: \n {defs}""".format(defs = '\n\n 1. ' + '\n\n 1. '.join(list(bb_korpus.keys()))))
printmd("""### Korpus definert""")
# Out:
# ### Korpus definert

# %% [markdown]
# ## Narrative buer
#
# Basert på Kurt Vonneguts video om narrative buer: [![video](https://img.youtube.com/vi/GOGru_4z1Vc/0.jpg)](https://www.youtube.com/watch?v=GOGru_4z1Vc&t=249s)

# %% [markdown]
# ## Liste over URNene i korpuset med metadata.
#
# URN-ene ligger i BB.Urn.alle

# %%
urnlist = nb.frame(nb.metadata(bb_korpus['BB.Urn.alle']), ['urn', 'forfatter', 'år', 'tittel', 'utgiver', 'språk', 'oversatt fra'])
urnlist
# Out:
#                urn                    forfatter    år  \
# 0    2015092329004       Abrahamsen, Olav Arild  1987
# 1    2013091708052               Engen, Arnfinn  1988
# 2    2011022808060                 Flyen, Simen  2002
# 3    2016060848167                 Thorson, Odd  1981
# 4    2007072404055              Jacobsen, Kjell  1977
# 5    2010110808243                Fossen, Kjell  1991
# 6    2016031048098                  Dørum, Knut  2013
# 7    2010022503019               Wikan, Steinar  1995
# 8    2015082548199            Lindanger, Birger  1996
# 9    2013091708049             Nordås, Hallvard  1989
# 10   2015013008162               Sande, Jostein  1999
# 11   2010030810008              Danielsen, Rolf  1997
# 12   2007091901053               Moren, Gudmund  1991
# 13   2016011848088         Eikeset, Kjell Roger  2003
# 14   2013071608037                Dehli, Martin  1987
# 15   2009021000103                  Kolle, Nils  1999
# 16   2011032108123            Eliassen, Sven G.  2004
# 17   2008021300004                Benum, Edgeir  1994
# 18   2016031548001             Petterson, Arvid  1994
# 19   2011062108120                 Hals, Harald  1978
# 20   2014100338137        Fossen, Anders Bjarne  1998
# 21   2011092608191           Angell, Svein Ivar  2004
# 22   2011010508117               Hovland, Edgar  1995
# 23   2013091038001         Christophersen, Egil  2009
# 24   2013043007081             Svendsen, Åsmund  2010
# 25   2011061605068                   Thue, Lars  1984
# 26   2011022808053                Asphaug, Arne  2001
# 27   2011021108014          Solhjell, Kåre Olav  1995
# 28   2007112701007                Asphaug, Arne  1992
# 29   2014022708170              Andresen, Astri  1994
# ..             ...                          ...   ...
# 121  2014062548132  Vangsnes, Ella Marie Brekke  2003
# 122  2013121806056       Balsvik, Randi Rønning  1989
# 123  2007083104015              Ohnstad, Anders  1990
# 124  2013050708052       Holm, Christian Hintze  1996
# 125  2014100338139                  Dørum, Knut  2008
# 126  2010030810004        Fossen, Anders Bjarne  1995
# 127  2014100808001       Holm, Christian Hintze  2000
# 128  2011080508017                  Dørum, Knut  2007
# 129  2011050608001               Feiring, Trond  2004
# 130  2015072308166          Jansen, Leonhard B.  1994
# 131  2015090348036                  Alsvik, Ola  2006
# 132  2011091408122               Hosar, Hans P.  1998
# 133  2008052900048            Sivertsen, Jørgen  1973
# 134  2010110808137                Fossen, Kjell  1991
# 135  2016090848297          Johansen, Karl Egil  1993
# 136  2010102820005              Berggren, Magne  1990
# 137  2013050708008                 Flyen, Simen  1996
# 138  2011030108024          Solhjell, Kåre Olav  2000
# 139  2012071324009                               1975
# 140  2008090500043           Figueiredo, Ivo de  1999
# 141  2013070406024                Dehli, Martin  1973
# 142  2010090208019               Dybdahl, Audun  1995
# 143  2007092000088               Tøsse, Sigvart  1991
# 144  2011080308062              Schrumpf, Ellen  2006
# 145  2011012403048             Ruud, Marit Ekne  2010
# 146  2009031904063             Svendsen, Oddvar  2002
# 147  2010120120001        Sandvik, Pål Thonstad  1999
# 148  2013050707014                 Aas, Steinar  2001
# 149  2014110448226                  Seland, Per  2011
# 150  2009082004068                    Moen, Eli  1993
#
#                                        tittel  \
# 0                       Flekkefjords historie
# 1                          Endring og oppbrot
# 2                     Eidsvoll bygds historie
# 3                                     Drammen
# 4    Fra århundreskiftet til frigjøringsvåren
# 5                                    Laksevåg
# 6                           Byen blir sentrum
# 7                          Grensebygda Neiden
# 8                                   Randaberg
# 9                                   1870-1989
# 10                                 Tidsskifte
# 11                       exempelløs fremgang"
# 12                           Mot vår egen tid
# 13    [Den mangfoldige bygdebyen (1964-2002)]
# 14                   Fredrikstad bys historie
# 15                    Bygdebok for Kvam herad
# 16                                  1930-1992
# 17                           Byråkratienes by
# 18                     Småfolk og drivkrefter
# 19                       Lillestrøms historie
# 20                            Askøys historie
# 21                    Bygd nær byen 1840-1972
# 22                            Hadsel bygdebok
# 23                         Nøtterøys historie
# 24                                     Hvaler
# 25                                      Asker
# 26                                   Øygarden
# 27            Bygdehistorie for Nore og Uvdal
# 28                                   Øygarden
# 29                Handelsfolk og fiskerbønder
# ..                                        ...
# 121                         Heilt andre tider
# 122                                     Vardø
# 123                          Aurland bygdebok
# 124                       Vekst og forandring
# 125                        -midt mellom byene
# 126                    Byen sprenger grensene
# 127                 Sommeridyll og krisetider
# 128                 Ås bygdebokverk 1850-2010
# 129                             Byen og bygda
# 130                             Valle kommune
# 131                              Storkommunen
# 132                            Skjåk bygdebok
# 133                                Hammerfest
# 134                                  Laksevåg
# 135                          Fanabu og bymann
# 136                       Tiden 1800 til 1980
# 137                           Nes på Romerike
# 138           Bygdehistorie for Nore og Uvdal
# 139                  Stavanger på 1800-tallet
# 140                  Fredrikstad bys historie
# 141                  Fredrikstad bys historie
# 142                                 1814-1940
# 143                        Bygdebok for Tydal
# 144                             Byen ved elva
# 145                             Gjøvik 150 år
# 146    Storhetstid, brytningstid, framtidshåp
# 147                    Kristiansands historie
# 148                    Byen, banen og bolaget
# 149                                    Sirdal
# 150                Modum - ei bygd, tre elver
#
#                                                utgiver språk oversatt fra
# 0    [Flekkefjord sparebank];Flekkefjord : [Flekkef...   nob
# 1    Gausdal kommune;[Gausdal] : Gausdal kommune, 1...   nno
# 2    Eidsvoll kommune;[Eidsvoll] : Eidsvoll kommune...   nob
# 3    Drammen kommune;Drammen : Drammen kommune, 196...   nob
# 4    Vefsn kommune;Mosjøen : Vefsn kommune, 1970-    .   mul
# 5       Bergen kommune;[Bergen] : Bergen kommune, 1991   nob
# 6    Tapir akademisk forl.;Trondheim : Tapir akadem...   nob
# 7          Nordkalott-forl.;Sør-Varanger museums forl.   nob
# 8           Kommunen;[Randaberg] : Kommunen, 1983-2013   nno
# 9    Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...   nno
# 10    Sogelaget;[Sunndalsøra] : Sogelaget, 1965-[1999]   nno
# 11   Universitetsforl.;Oslo : Universitetsforl., co...   nob
# 12   Gausdal kommune;[Gausdal] : Gausdal kommune, 1...   nob
# 13       Alta kommune;[Alta] : Alta kommune, 1990-2003   nob
# 14         Kommunen;Fredrikstad : Kommunen, 1960-    .   nob
# 15          Kvam herad;Norheimsund : Kvam herad, 1999-   nno
# 16         Tune kommune;Tune : Tune kommune, 1978-2004   nob
# 17               Cappelen;[Oslo] : Cappelen, 1990-1994   nob
# 18   Porsanger kommune;[Lakselv] : Porsanger kommun...   nob
# 19                   Kommunen;Skedsmo : Kommunen, 1978   und
# 20   [Askøy kommune];[Kleppestø] : [Askøy kommune],...   nob
# 21   Vigmostad &amp; Bjørke;Bergen : Alma mater, co...   nno
# 22   Hadsel bygdehistorienemnd;[Stokmarknes?] : Had...   nob
# 23   Nøtterøy kommune;[Borgheim] : Nøtterøy kommune...   nob
# 24                                           Aschehoug   nob
# 25   Universitetsforl.;Oslo : Universitetsforl., 19...   nob
# 26   Øygarden kommune;Tjeldstø : Øygarden kommune, ...   nno
# 27   Nore og Uvdal kommune;[Nore] : Nore og Uvdal k...   nno
# 28   Øygarden kommune;Tjeldstø : Øygarden kommune, ...   nno
# 29   Tromsø kommune;[Tromsø] : Tromsø kommune, 1994...   nob
# ..                                                 ...   ...          ...
# 121  Fusa kommune;Eikelandsosen : Fusa kommune, 200...   nno
# 122  Vardø kommune ; Stavanger : Dreyer Bok;Vardø :...   nob
# 123        Sogelaget;[Aurland] : Sogelaget, 1962-    .   nno
# 124  Frogn kommune;[Drøbak] : Frogn kommune, 1996- ...   nob
# 125      Råde kommune;[Råde] : Råde kommune, 2002-2013   nob
# 126               Alma mater;Bergen : Alma mater, 1995   nob
# 127  Frogn kommune;[Drøbak] : Frogn kommune, 1996- ...   nob
# 128              Ås kommune;Ås : Ås kommune, 2007-2012   nob
# 129  Thorsrud, Lokalhistorisk forl.;Lillehammer : T...   nob
# 130          Valle kommune;Valle : Valle kommune, 1994   nno
# 131  Brøttum historielag;[Brumunddal] : Brøttum his...   nob
# 132  Skjåk kommune;[Skjåk] : Skjåk kommune, 1994-    .   nno
# 133                                           Kommunen   nob
# 134     Bergen kommune;[Bergen] : Bergen kommune, 1991   nob
# 135  Fana bygdebokmemnd;Bergen : Fana bygdebokmemnd...   nno
# 136  Rygge sparebank;[Rygge] : Rygge sparebank, 195...   nob
# 137       Nes kommune;[Årnes] : Nes kommune, 1996-1998   nob
# 138  Nore og Uvdal kommune;[Nore] : Nore og Uvdal k...   nno
# 139                   I hovedkommisjon hos Stabenfeldt   nob
# 140        Kommunen;Fredrikstad : Kommunen, 1960-    .   nob
# 141        Kommunen;Fredrikstad : Kommunen, 1960-    .   nob
# 142  Rissa bygdeboknevnd;Trondheim : Rissa bygdebok...   nob
# 143     Tydal kommune;Tydal : Tydal kommune, 1987-1994   nob
# 144  Porsgrunn kommune;Porsgrunn : Porsgrunn kommun...   nob
# 145  Alfa forl. i samarbeid med Gjøvik kommune;Gjøv...   nob
# 146  Stiftelsen Narviks historieverk;Narvik : Stift...   nob
# 147                                  Sparebanken pluss   nob
# 148  Stiftelsen Narviks historieverk;Narvik : Stift...   nob
# 149            Kommunen;Tonstad : Kommunen, 1980-    .   nob
# 150                                      Modum kommune   nob
#
# [151 rows x 7 columns]

# %% [markdown]
# ### Finne frem til bøker
#
# Bruk **urnlist** for å referere til en bok. Cellen under gir et idiom for å finne frem bøker basert på forfatter. Det er mulig å lage kortkommandoer som gjør ting litt enklere, bare si fra hvordan dere vil det skal være. Hvis det er greit som det vises i cellen under, går det fint. Bare bytt ut forfatternavnet med et annet.

# %%
urnlist[urnlist['forfatter'].str.contains('Alsvik')]
# Out:
#                urn    forfatter    år                  tittel  \
# 90   2013062406124  Alsvik, Ola  2001          I krig og fred
# 92   2013091708048  Alsvik, Jan  1989               1800-1870
# 105  2011031103008  Alsvik, Ola  1998  Historien om Lørenskog
# 131  2015090348036  Alsvik, Ola  2006            Storkommunen
#
#                                                utgiver språk oversatt fra
# 90   Brøttum historielag;[Brumunddal] : Brøttum his...   nob
# 92   Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...   nno
# 105                                  Lørenskog kommune   nob
# 131  Brøttum historielag;[Brumunddal] : Brøttum his...   nob

# %% [markdown]
# ### Sett av ord for å sjekke mot.
#
# Lag en liste av ord for å se utviklingen, listen kan være enkeltord er flere ord. Definer dem som i mønsteret nedenfor, og sett variabelen inn i kommandoen for vekstdiagrammet.

# %%
traktor = """traktor, Traktor, traktoren, Traktoren""".split(', ')

# %%
gårdsord = """låve, Låve, Låven, låven, fjøs, fjøsen, fjøset, Fjøsen, Fjøset""".split(', ')

# %%
kvinneord = """kvinnfolk, kvinnfolka, kvinner, jenter, jenta, jenten, datter, dattera, kone, konen""".split(', ')

# %% [markdown]
# ## Lag buer for ordene i en bestemt bok
#
# Finn URN-en som i ovenfor, klipp ut selve URN-referansen og lim inn den inn i kommandoen under. Kopier cellen og lim inn så mange kopier det trengs.

# %%
plot(2013062406124 , {'Q': kvinneord, 'G': gårdsord}, window=5000, pr=100);
