# %% [markdown]
# ### Oppstart

# %% [markdown]
# ### Preamble

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, printmd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def plot(urn , wordbag, window=5000, pr=100, lw=3, alpha=0.8):
    md = nb.metadata(urn)[0][1:4]
    #print(md)
    x = nb.plot_book_wordbags(urn , wordbag, window=5000, pr=100)
    x.plot(figsize=(12, 5), lw=lw, alpha=alpha, title=', '.join([str(m) for m in md]))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
update('nbtext', overwrite=True)
import nbtext as nb
import os
from nbtext import vekstdiagram, make_graph, get_urn, relaterte_ord

# %matplotlib inline
# Out:
# Updated file `/home/lars/Lokalhistorie/nbtext.py`

# %%
_,_,korpusfiles = next(os.walk('./Analysekorpus'))
bb_korpus = dict()
for f in korpusfiles:
    bb_korpus[f.split('.docx')[0]] = list(set(nb.get_urns_from_docx(os.path.join('./Analysekorpus', f))))
#printmd("""## Delkorpus: \n {defs}""".format(defs = '\n\n 1. ' + '\n\n 1. '.join(list(bb_korpus.keys()))))
printmd("""### Korpus definert""")
# Out:
# ### Korpus definert

# %% [markdown]
# ## Narrative buer
#
# Basert på Kurt Vonneguts video om narrative buer: [![video](https://img.youtube.com/vi/GOGru_4z1Vc/0.jpg)](https://www.youtube.com/watch?v=GOGru_4z1Vc&t=249s)

# %% [markdown]
# ## Liste over URNene i korpuset med metadata.
#
# URN-ene ligger i BB.Urn.alle

# %%
urnlist = nb.frame(nb.metadata(bb_korpus['BB.Urn.alle']), ['urn', 'forfatter', 'år', 'tittel','subtittel', 'utgiver', 'sjanger','sesamid', 'språk', 'oversatt fra'])
urnlist
# Out:
#                urn                    forfatter    år  \
# 0    2012071324009                               1975
# 1    2013081224003             Ertresvaag, Egil  1982
# 2    2013071608037                Dehli, Martin  1987
# 3    2007112701007                Asphaug, Arne  1992
# 4    2008101304040             Bjørnhaug, Inger  2000
# 5    2007092000088               Tøsse, Sigvart  1991
# 6    2011050608001               Feiring, Trond  2004
# 7    2013091708049             Nordås, Hallvard  1989
# 8    2007111904010          Hauglid, Anders Ole  1991
# 9    2016090948140               Paulsen, Helge  1986
# 10   2014062606076                               1987
# 11   2007091901053               Moren, Gudmund  1991
# 12   2009042704019           Andressen, Leif T.  1994
# 13   2011101408066                 Hals, Harald  1978
# 14   2013061938074                 Evjen, Bjørg  2001
# 15   2016011848088         Eikeset, Kjell Roger  2003
# 16   2013050708052       Holm, Christian Hintze  1996
# 17   2014111807526  Vangsnes, Ella Marie Brekke  2005
# 18   2010030810004        Fossen, Anders Bjarne  1995
# 19   2007083104015              Ohnstad, Anders  1990
# 20   2013071205104                Dehli, Martin  1993
# 21   2008031104030                 Nordby, Guro  1995
# 22   2013043007081             Svendsen, Åsmund  2010
# 23   2015021048042                 Aas, Steinar  2014
# 24   2008090500043           Figueiredo, Ivo de  1999
# 25   2013082606089                               1977
# 26   2013091708052               Engen, Arnfinn  1988
# 27   2011090108160            Nerbøvik, Jostein  1997
# 28   2008022104028        Timberlid, Jan Anders  1995
# 29   2013050708008                 Flyen, Simen  1996
# ..             ...                          ...   ...
# 121  2012061324001                  Lunde, Aage  1979
# 122  2008011501091                Forbord, Kåre  1993
# 123  2011051608083                Asphaug, Arne  2006
# 124  2013101808032                               1979
# 125  2010072008014          Gjerdåker, Johannes  1990
# 126  2014062548132  Vangsnes, Ella Marie Brekke  2003
# 127  2011062108082                  Lunde, Aage  1983
# 128  2012010524015       Abrahamsen, Olav Arild  1994
# 129  2007100504012                 Aass, Eivind  1991
# 130  2011030108024          Solhjell, Kåre Olav  2000
# 131  2010090208019               Dybdahl, Audun  1995
# 132  2011110208107       Hanssen, Einar Richter  2004
# 133  2011061605068                   Thue, Lars  1984
# 134  2011092608191           Angell, Svein Ivar  2004
# 135  2014100338139                  Dørum, Knut  2008
# 136  2015090348036                  Alsvik, Ola  2006
# 137  2007092504001            Kjeldstadli, Knut  1990
# 138  2013050708028                               1980
# 139  2011010603001        Fossen, Anders Bjarne  1996
# 140  2011080308062              Schrumpf, Ellen  2006
# 141  2016031048098                  Dørum, Knut  2013
# 142  2008030404031                Asphaug, Arne  1995
# 143  2013091708048                  Alsvik, Jan  1989
# 144  2010111008051              Øvrelid, Ragnar  1991
# 145  2016090848297          Johansen, Karl Egil  1993
# 146  2013102806011                               1983
# 147  2012060724006                  Dahl, Helge  1984
# 148  2007112300034                  Roset, Ivar  1990
# 149  2010110808243                Fossen, Kjell  1991
# 150  2013121806056       Balsvik, Randi Rønning  1989
#
#                                       tittel  \
# 0                   Stavanger på 1800-tallet
# 1                      bysamfunn i utvikling
# 2                   Fredrikstad bys historie
# 3                                   Øygarden
# 4                          Dølaby, verdensby
# 5                         Bygdebok for Tydal
# 6                              Byen og bygda
# 7                                  1870-1989
# 8          Balsfjorden og Malangens historie
# 9                                   Nøtterøy
# 10                      Bygdebok for Meråker
# 11                          Mot vår egen tid
# 12                         Moss bys historie
# 13                      Lillestrøms historie
# 14                          Tysfjord kommune
# 15   [Den mangfoldige bygdebyen (1964-2002)]
# 16                       Vekst og forandring
# 17                         Heilt andre tider
# 18                    Byen sprenger grensene
# 19                          Aurland bygdebok
# 20                  Fredrikstad bys historie
# 21                                 1940-1992
# 22                                    Hvaler
# 23                              Forvandlinga
# 24                  Fredrikstad bys historie
# 25                   Selbu i fortid og nåtid
# 26                        Endring og oppbrot
# 27                      Volda-soga 1800-1945
# 28                       Bygdebok for Gaular
# 29                           Nes på Romerike
# ..                                       ...
# 121                   Sør-Varangers historie
# 122                          Malvik bygdebok
# 123                                 Øygarden
# 124                 Soga om Gloppen og Breim
# 125                     Ålmenn soge for Voss
# 126                        Heilt andre tider
# 127             Bygdehistorien fram til 1964
# 128                                1940-1964
# 129                           Byen som brant
# 130          Bygdehistorie for Nore og Uvdal
# 131                                1814-1940
# 132                    Lyngen regionhistorie
# 133                                    Asker
# 134                  Bygd nær byen 1840-1972
# 135                       -midt mellom byene
# 136                             Storkommunen
# 137                               delte byen
# 138                          Nes på Romerike
# 139                          Askøys historie
# 140                            Byen ved elva
# 141                        Byen blir sentrum
# 142                                 Øygarden
# 143                                1800-1870
# 144                         Historia om Fron
# 145                         Fanabu og bymann
# 146                    Soga om Sola og Madla
# 147                                   Rjukan
# 148                      Sarpsborg 1939-1945
# 149                                 Laksevåg
# 150                                    Vardø
#
#                                              subtittel  \
# 0
# 1                                            1800-1920
# 2
# 3
# 4
# 5
# 6              materiell vekst og kulturell blomstring
# 7
# 8
# 9                                           1800-årene
# 10
# 11                                           1914-1980
# 12
# 13
# 14
# 15
# 16     Frogn og Drøbak fra ca 1825 til århundreskiftet
# 17                                      Fusa 1900-2000
# 18                                           1920-1972
# 19                                       fra 1835-1985
# 20
# 21
# 22                      en samtidshistorie : 1945-2000
# 23                          Bodøs historie : 1890-1950
# 24
# 25
# 26                                           1830-1914
# 27
# 28
# 29
# ..                                                 ...
# 121
# 122
# 123
# 124
# 125                               frå 1800 til vår tid
# 126                                     Fusa 1900-2000
# 127
# 128                       krig - gjenoppbygging- vekst
# 129                             Kristiansund 1900-1942
# 130
# 131
# 132
# 133                                          1840-1980
# 134
# 135                                          1830-1940
# 136                                          Ringsaker
# 137                                  fra 1900 til 1948
# 138
# 139
# 140
# 141                         Bodøs historie : 1816-1890
# 142
# 143
# 144
# 145                                          1870-1972
# 146
# 147
# 148                                   okkupasjonstiden
# 149  strandstedet, jordbruks- og fiskerlandet ved s...
# 150                   grensepost og fiskevær 1850-1950
#
#                                                utgiver     sjanger  \
# 0                     I hovedkommisjon hos Stabenfeldt  notfiction
# 1    Universitetsforl.;Bergen : Universitetsforl., ...     unknown
# 2          Kommunen;Fredrikstad : Kommunen, 1960-    .  notfiction
# 3    Øygarden kommune;Tjeldstø : Øygarden kommune, ...  notfiction
# 4    Thorsrud, Lokalhistorisk forl.;Lillehammer : T...  notfiction
# 5       Tydal kommune;Tydal : Tydal kommune, 1987-1994  notfiction
# 6    Thorsrud, Lokalhistorisk forl.;Lillehammer : T...  notfiction
# 7    Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...     fiction
# 8       Kommunen;[Storsteinnes] : Kommunen, 1981-    .  notfiction
# 9                                     Nøtterøy kommune
# 10   Meråker kommune;[Meråker] : Meråker kommune, 1...  notfiction
# 11   Gausdal kommune;[Gausdal] : Gausdal kommune, 1...  notfiction
# 12       Moss kommune;[Moss] : Moss kommune, 1984-1994  notfiction
# 13                   Kommunen;Skedsmo : Kommunen, 1978  notfiction
# 14           Kommunen;[Kjøpsvik] : Kommunen, 1998-2001  notfiction
# 15       Alta kommune;[Alta] : Alta kommune, 1990-2003  notfiction
# 16   Frogn kommune;[Drøbak] : Frogn kommune, 1996- ...  notfiction
# 17   Fusa kommune;Eikelandsosen : Fusa kommune, 200...  notfiction
# 18                Alma mater;Bergen : Alma mater, 1995  notfiction
# 19         Sogelaget;[Aurland] : Sogelaget, 1962-    .  notfiction
# 20         Kommunen;Fredrikstad : Kommunen, 1960-    .  notfiction
# 21   [Bygdebokkomiteen];Ullensaker : [Bygdebokkomit...  notfiction
# 22                                           Aschehoug  notfiction
# 23   Tapir akademisk forl.;Trondheim : Tapir akadem...  notfiction
# 24         Kommunen;Fredrikstad : Kommunen, 1960-    .  notfiction
# 25           Kommunen;[Selbu] : Kommunen, 1972-[1992?]  notfiction
# 26   Gausdal kommune;[Gausdal] : Gausdal kommune, 1...  notfiction
# 27     Volda kommune;Volda : Volda kommune, 1996-2004.  notfiction
# 28   [Gaular sogenemnd];[Høyanger] : [Gaular sogene...  notfiction
# 29        Nes kommune;[Årnes] : Nes kommune, 1996-1998  notfiction
# ..                                                 ...         ...
# 121                               Sør-Varanger kommune  notfiction
# 122  Malvik kommune;Trondheim : Globus-forlaget, 19...  notfiction
# 123  Øygarden kommune;Tjeldstø : Øygarden kommune, ...  notfiction
# 124                 Banken;Sandane : Banken, 1978-2001  notfiction
# 125  Voss bygdeboknemnd;[Voss] : Voss bygdeboknemnd...  notfiction
# 126  Fusa kommune;Eikelandsosen : Fusa kommune, 200...  notfiction
# 127         Kommunen;[Eidsvoll] : Kommunen, 1983-1986.  notfiction
# 128   Molde kommune;[Molde] : Molde kommune, 1962-1994  notfiction
# 129  I kommisjon hos Barmans bokhandel;Kristiansund...  notfiction
# 130  Nore og Uvdal kommune;[Nore] : Nore og Uvdal k...  notfiction
# 131  Rissa bygdeboknevnd;Trondheim : Rissa bygdebok...  notfiction
# 132  Lyngen bygdebok;[Lyngseidet] : Lyngen bygdebok...  notfiction
# 133  Universitetsforl.;Oslo : Universitetsforl., 19...  notfiction
# 134  Vigmostad &amp; Bjørke;Bergen : Alma mater, co...  notfiction
# 135      Råde kommune;[Råde] : Råde kommune, 2002-2013  notfiction
# 136  Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 137              Cappelen;[Oslo] : Cappelen, 1990-1994  notfiction
# 138             Kommunen;[Årnes] : Kommunen, 1958-1980     unknown
# 139  [Askøy kommune];[Kleppestø] : [Askøy kommune],...  notfiction
# 140  Porsgrunn kommune;Porsgrunn : Porsgrunn kommun...  notfiction
# 141  Tapir akademisk forl.;Trondheim : Tapir akadem...  notfiction
# 142  Øygarden kommune;Tjeldstø : Øygarden kommune, ...  notfiction
# 143  Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...  notfiction
# 144  Fron historielag;Vinstra : Fron historielag, 1...  notfiction
# 145  Fana bygdebokmemnd;Bergen : Fana bygdebokmemnd...  notfiction
# 146        Sola kommune;Sola : Sola kommune, 1980-   .  notfiction
# 147      Tinn kommune;Rjukan : Tinn kommune, 1983-1984     unknown
# 148                                  Sarpsborg kommune  notfiction
# 149     Bergen kommune;[Bergen] : Bergen kommune, 1991  notfiction
# 150  Vardø kommune ; Stavanger : Dreyer Bok;Vardø :...  notfiction
#
#                               sesamid språk oversatt fra
# 0    52f13940bde75d3097781a7f213f439b   nob
# 1    2cff14caa9328f1fad5cb7d25e47935a   nob
# 2    a58ff37a87ba85d0d480099cf6837bc3   nob
# 3    830bad89b48b7e6b031b3dd47fafaec1   nno
# 4    1e80a4c177b0f743e0cc9a60d5512f0c   nob
# 5    95d3cc146d182cb4e5d7842ee82eb2d6   nob
# 6    3b097a83491511314392b4f337dbab9c   nob
# 7    9917f589d103511b39892997d943818a   nno
# 8    157871c346cb02cf30a1541b922c3c17   nob
# 9    4f3fd9434f6e99aff9de87164fe05ef8   nob
# 10   c63396a71fe847a243ae6725655c136f   nob
# 11   02d799822ad7f964e4c6c2555680d4c9   nob
# 12   6454e8377d212eebb019faafc4aa3709   nob
# 13   d112a1c287bdae8becce80d50e6bc1f1   und
# 14   3d3815ff4b6642174b44e1f3fff493be   nob
# 15   2cdbf8dd8ab9c3525cd626eec7d6c680   nob
# 16   67d7b8c93eed9a24025f5b9e75255fca   nob
# 17   6b0ae5e01425252ab3ab16df9c79a12a   nno
# 18   7d96702b85f883f62f1d6c155cff13cb   nob
# 19   04b078dc51ec9a23bc8fcbe59de78e71   nno
# 20   8442a69da9a384831abb72c4b31a90af   nob
# 21   fae4d76a6a4908310fa6ecd6ea08c704   nob
# 22   5c02e8dcc5d77557fdcca6e0eb7d7a0e   nob
# 23   e8dac3ff9786d589d393bd2a4601012f   nob
# 24   72ddd57274a01156ec840cc05d89588f   nob
# 25   1557b0b1b118195f94a881a2a9531280   nob
# 26   28a58067afb476c6c24a5ca6228c00db   nno
# 27   9aa139a2ffec95faee8de4fa6b0a8a26   nno
# 28   016b5611f5d2cb5a29709b97a8d1f320   nno
# 29   9584a338ab1a670df3647f5c70f6cf2f   nob
# ..                                ...   ...          ...
# 121  0aee8ab0124bf9a6ecc11d855e5c61e6   nob
# 122  f1c04bf6a0d5da3d96ab44c7fb4e5a92   nob
# 123  31a2d3daf843269b76b977e02d7a1cc6   nno
# 124  8add46a3b09d65e742ea8c51ee59e030   und
# 125  71af72df1a013d7d8c6da84cb5f8ed95   nno
# 126  d524633344ab5aecbd228b61c808f650   nno
# 127  4e0fb6b9aea04eb74017a0d747488d44   nob
# 128  7481a95c1bc2b9b1eb3528ab997687da   nob
# 129  d5a63a5e0078b1adfbab96efda592ade   nob
# 130  a1ac1fd17207235882d878e573352caf   nno
# 131  0bfe73ffeea4008a11d4bdb33cef5aaa   nob
# 132  fba1ac0d3328a9fd6c0547e52f0d3f74   nob
# 133  620b5a01f9afe84fd78ecb035a2f5290   nob
# 134  50e0145f08949e95d8d0528d4c106735   nno
# 135  5d9ce09fe14d70d9ff84150e8e2873ed   nob
# 136  5821efc1f73613aa430f9afffe0ba91a   nob
# 137  ea74e85afaf700b2a84df484f48ae629   nob
# 138  a575b29c4b8118e46cb3f607bc44900a   nob
# 139  c9d7e43a513859c2347333d5e3fa29f1   nob
# 140  3a8390b456091fd962333081b8c30c7c   nob
# 141  ca5008b28c0f691553c0859bd6e52495   nob
# 142  f4c788dafc1c4f131823c13874e49141   nno
# 143  cf0de84772e5e12c81790a2d47136b12   nno
# 144  c7cd3b99ccdc50695fd2254ece5cbbb4   nno
# 145  656b9ae5f3b262c79ec7a8e69e4513db   nno
# 146  ec4e57bfc0f47c83922691c7dcc47ae7   nno
# 147  13918ae79a42196a990e906a79128f76   nob
# 148  7fb4ff3182cb31ef6b78af1d0e1971f9   nob
# 149  d77897cf05fb90c444ae04d5b95e9b8f   nob
# 150  f44018a116994a564221759c3deaee5d   nob
#
# [151 rows x 10 columns]

# %% [markdown]
# ### Finne frem til bøker
#
# Bruk **urnlist** for å referere til en bok. Cellen under gir et idiom for å finne frem bøker basert på forfatter. Det er mulig å lage kortkommandoer som gjør ting litt enklere, bare si fra hvordan dere vil det skal være. Hvis det er greit som det vises i cellen under, går det fint. Bare bytt ut forfatternavnet med et annet.

# %%
urnlist[urnlist['forfatter'].str.contains('Alsvik, Ola')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-03162938f7a2> in <module>()
# ----> 1 urnlist[urnlist['forfatter'].str.contains('Alsvik, Ola')]
#
# NameError: name 'urnlist' is not defined

# %% [markdown]
# ### Sett av ord for å sjekke mot.
#
# Lag en liste av ord for å se utviklingen, listen kan være enkeltord er flere ord. Definer dem som i mønsteret nedenfor, og sett variabelen inn i kommandoen for vekstdiagrammet.

# %%
traktor = """traktor, Traktor, traktoren, Traktoren""".split(', ')

# %%
gårdsord = """låve, Låve, Låven, låven, fjøs, fjøsen, fjøset, Fjøsen, Fjøset""".split(', ')

# %%
kvinneord = """kvinnfolk, kvinnfolka, kvinner, jenter, jenta, jenten, datter, dattera, kone, konen""".split(', ')

# %% [markdown]
# ## Lag buer for ordene i en bestemt bok
#
# Finn URN-en som i ovenfor, klipp ut selve URN-referansen og lim inn den inn i kommandoen under. Kopier cellen og lim inn så mange kopier det trengs.

# %%
plot(2013062406124 , {'Q': kvinneord, 'G': gårdsord}, window=5000, pr=100);
