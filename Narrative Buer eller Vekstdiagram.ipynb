# %% [markdown]
# ### Oppstart

# %% [markdown]
# ### Preamble

# %%
from dhlab.module_update import update, css, printmd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def plot(urn , wordbag, window=5000, pr=100, lw=3, alpha=0.8):
    try:
        md = nb.metadata(urn)[0][1:4]
    except:
        md = ['x','y','z','u']
    #print(md)
    x = nb.plot_book_wordbags(urn , wordbag, window=window, pr=pr)
    x.plot(figsize=(12, 5), lw=lw, alpha=alpha, title=', '.join([str(m) for m in md]))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import dhlab.nbtext as nb
import os
from nbtext import vekstdiagram, make_graph, get_urn, relaterte_ord

# %matplotlib inline

# %%
_,_,korpusfiles = next(os.walk('./Analysekorpus'))
bb_korpus = dict()
for f in korpusfiles:
    bb_korpus[f.split('.docx')[0]] = list(set(nb.get_urns_from_docx(os.path.join('./Analysekorpus', f))))
#printmd("""## Delkorpus: \n {defs}""".format(defs = '\n\n 1. ' + '\n\n 1. '.join(list(bb_korpus.keys()))))
printmd("""### Korpus definert""")
# Out:
# ### Korpus definert

# %% [markdown]
# ## Narrative buer
#
# Basert på Kurt Vonneguts video om narrative buer: [![video](https://img.youtube.com/vi/GOGru_4z1Vc/0.jpg)](https://www.youtube.com/watch?v=GOGru_4z1Vc&t=249s)

# %% [markdown]
# ## Liste over URNene i korpuset med metadata.
#
# URN-ene ligger i BB.Urn.alle

# %%
bb_korpus['BB.Urn.alle']
# Out:
# ['2018032348039',
#  '2014062606076',
#  '2018030748143',
#  '2014100808001',
#  '2010030810004',
#  '2013091708048',
#  '2013101808032',
#  '2011092608191',
#  '2013082606089',
#  '2011040708135',
#  '2009082004068',
#  '2007083104015',
#  '2016090948140',
#  '2008021300004',
#  '2013050708007',
#  '2007091901053',
#  '2013070406024',
#  '2015101448015',
#  '2013091038001',
#  '2015030208110',
#  '2011090108160',
#  '2012061324001',
#  '2014092438001',
#  '2011021108014',
#  '2013121806056',
#  '2016090848297',
#  '2011091608262',
#  '2007100504012',
#  '2008022104028',
#  '2008072500055',
#  '2015072308166',
#  '2011022808060',
#  '2018030548032',
#  '2013102806011',
#  '2015041608003',
#  '2013050708008',
#  '2013050708052',
#  '2016060848167',
#  '2017061207088',
#  '2017030348114',
#  '2014062548132',
#  '2017031748064',
#  '2010030810009',
#  '2013071205104',
#  '2015013008162',
#  '2016010807501',
#  '2011032408002',
#  '2009031904063',
#  '2010111008051',
#  '2016090648017',
#  '2008090500043',
#  '2016060848208',
#  '2014013105049',
#  '2011061605068',
#  '2007112300034',
#  '2007121004104',
#  '2010092703016',
#  '2017040348068',
#  '2008102100036',
#  '2011022808053',
#  '2013120206040',
#  '2007092000088',
#  '2011012403048',
#  '2007081400086',
#  '2017010648094',
#  '2017030648006',
#  '2008101304040',
#  '2014100338139',
#  '2014090306064',
#  '2008052600012',
#  '2011032108123',
#  '2013050707014',
#  '2008011501091',
#  '2011030108024',
#  '2011082308146',
#  '2011051608083',
#  '2007112701007',
#  '2009042704019',
#  '2010092203016',
#  '2011022808075',
#  '2018030748131',
#  '2012052224021',
#  '2015090348036',
#  '2012071324009',
#  '2011050608001',
#  '2010110808243',
#  '2017012748211',
#  '2013062038075',
#  '2014100338137',
#  '2017030648027',
#  '2015092329005',
#  '2011110208107',
#  '2015070608131',
#  '2018030648549',
#  '2015082548199',
#  '2011071508036',
#  '2007092504001',
#  '2007081400029',
#  '2013102806010',
#  '2007111904010',
#  '2018030748514',
#  '2008031104030',
#  '2008021200030',
#  '2010030810007',
#  '2010090608037',
#  '2013081224003',
#  '2017091948021',
#  '2007082200024',
#  '2011080308062',
#  '2017120548055',
#  '2010030810010',
#  '2007110804031',
#  '2018030748515',
#  '2012071138010',
#  '2011010603001',
#  '2011091408122',
#  '2017012748214',
#  '2012121038029',
#  '2011010508117',
#  '2011051608082',
#  '2018030748095',
#  '2014110448226',
#  '2010030810008',
#  '2018030748506',
#  '2013070938108',
#  '2010090208019',
#  '2010120120001',
#  '2008052900048',
#  '2007091704036',
#  '2017030648010',
#  '2010110808137',
#  '2014022708170',
#  '2015031629001',
#  '2018030748085',
#  '2011062108120',
#  '2018032048010',
#  '2018032048028',
#  '2018030648523',
#  '2010072008014',
#  '2015081208017',
#  '2007072404055',
#  '2012052224036',
#  '2015082608073',
#  '2012060724006',
#  '2017030648007',
#  '2014061948027',
#  '2011031103008',
#  '2013061938074',
#  '2013091708052',
#  '2011061605069',
#  '2013091708049',
#  '2011010408052',
#  '2008090904023',
#  '2011080508017',
#  '2011030708082',
#  '2011101408066',
#  '2009061104017',
#  '2013071608037',
#  '2009021000103',
#  '2015102906004',
#  '2008121000088',
#  '2013101708020',
#  '2016031548001',
#  '2015092329004',
#  '2008030404031',
#  '2013091738015',
#  '2015021048042',
#  '2011062108082',
#  '2012053108187',
#  '2016011848088',
#  '2014111807526',
#  '2013043007081',
#  '2012010524015',
#  '2015101448006',
#  '2017081748043',
#  '2017120548096',
#  '2013050708028',
#  '2010102820005',
#  '2013062406124',
#  '2018030748049',
#  '2008061000019',
#  '2016031048098',
#  '2010022503019']

# %%
nb.get_freq(2018030748131)
# Out:
# Counter()

# %%
nb.metadata(2018032348039)
# Out:
# []

# %%
nb.metadata(2007091901053)
# Out:
# [[2007091901053,
#   'Moren, Gudmund',
#   1991,
#   'Mot vår egen tid',
#   '1914-1980',
#   'Gausdal kommune;[Gausdal] : Gausdal kommune, 1987-1992',
#   'notfiction',
#   '02d799822ad7f964e4c6c2555680d4c9',
#   'nob',
#   '']]

# %%
urnlist = nb.frame(nb.metadata(bb_korpus['BB.Urn.alle']), ['urn', 'forfatter', 'år', 'tittel','subtittel', 'utgiver', 'sjanger','sesamid', 'språk', 'oversatt fra'])
urnlist
# Out:
#                urn                    forfatter    år  \
# 0    2014062606076                               1987
# 1    2014100808001       Holm, Christian Hintze  2000
# 2    2010030810004        Fossen, Anders Bjarne  1995
# 3    2013091708048                  Alsvik, Jan  1989
# 4    2013101808032                               1979
# 5    2011092608191           Angell, Svein Ivar  2004
# 6    2013082606089                               1977
# 7    2011040708135     Hansen, Runbjørg Bremset  2004
# 8    2009082004068                    Moen, Eli  1993
# 9    2007083104015              Ohnstad, Anders  1990
# 10   2016090948140               Paulsen, Helge  1986
# 11   2008021300004                Benum, Edgeir  1994
# 12   2013050708007                 Flyen, Simen  1998
# 13   2007091901053               Moren, Gudmund  1991
# 14   2013070406024                Dehli, Martin  1973
# 15   2015101448015                Gjerden, Knut  1993
# 16   2013091038001         Christophersen, Egil  2009
# 17   2015030208110            Eliassen, Sven G.  1994
# 18   2011090108160            Nerbøvik, Jostein  1997
# 19   2012061324001                  Lunde, Aage  1979
# 20   2014092438001             Berntsen, Harald  1995
# 21   2011021108014          Solhjell, Kåre Olav  1995
# 22   2013121806056       Balsvik, Randi Rønning  1989
# 23   2016090848297          Johansen, Karl Egil  1993
# 24   2011091608262       Abrahamsen, Olav Arild  2007
# 25   2007100504012                 Aass, Eivind  1991
# 26   2008022104028        Timberlid, Jan Anders  1995
# 27   2008072500055            Nerbøvik, Jostein  1996
# 28   2015072308166          Jansen, Leonhard B.  1994
# 29   2011022808060                 Flyen, Simen  2002
# ..             ...                          ...   ...
# 121  2011061605069            Myhre, Jan Eivind  1982
# 122  2013091708049             Nordås, Hallvard  1989
# 123  2011010408052         Nielsen, Jens Petter  1995
# 124  2008090904023          Gjerdåker, Brynjulv  1998
# 125  2011080508017                  Dørum, Knut  2007
# 126  2011030708082                 Flyen, Simen  2005
# 127  2011101408066                 Hals, Harald  1978
# 128  2009061104017                 Nordby, Guro  2002
# 129  2013071608037                Dehli, Martin  1987
# 130  2009021000103                  Kolle, Nils  1999
# 131  2015102906004                 Olstad, Finn  1997
# 132  2008121000088     Hansen, Runbjørg Bremset  2000
# 133  2013101708020               Paulsen, Helge  2003
# 134  2016031548001             Petterson, Arvid  1994
# 135  2015092329004       Abrahamsen, Olav Arild  1987
# 136  2008030404031                Asphaug, Arne  1995
# 137  2015021048042                 Aas, Steinar  2014
# 138  2011062108082                  Lunde, Aage  1983
# 139  2012053108187                               1971
# 140  2016011848088         Eikeset, Kjell Roger  2003
# 141  2014111807526  Vangsnes, Ella Marie Brekke  2005
# 142  2013043007081             Svendsen, Åsmund  2010
# 143  2012010524015       Abrahamsen, Olav Arild  1994
# 144  2015101448006               Feiring, Trond  1998
# 145  2013050708028                               1980
# 146  2010102820005              Berggren, Magne  1990
# 147  2013062406124                  Alsvik, Ola  2001
# 148  2008061000019       Balsvik, Randi Rønning  1989
# 149  2016031048098                  Dørum, Knut  2013
# 150  2010022503019               Wikan, Steinar  1995
#
#                                       tittel  \
# 0                       Bygdebok for Meråker
# 1                  Sommeridyll og krisetider
# 2                     Byen sprenger grensene
# 3                                  1800-1870
# 4                   Soga om Gloppen og Breim
# 5                    Bygd nær byen 1840-1972
# 6                    Selbu i fortid og nåtid
# 7                                Nærøyfolket
# 8                 Modum - ei bygd, tre elver
# 9                           Aurland bygdebok
# 10                                  Nøtterøy
# 11                          Byråkratienes by
# 12                           Nes på Romerike
# 13                          Mot vår egen tid
# 14                  Fredrikstad bys historie
# 15                          Bykle kultursoge
# 16                        Nøtterøys historie
# 17                         Rolvsøy 1500-1994
# 18                      Volda-soga 1800-1945
# 19                    Sør-Varangers historie
# 20         Hobøls historie fra 1800 til 1920
# 21           Bygdehistorie for Nore og Uvdal
# 22                                     Vardø
# 23                          Fanabu og bymann
# 24                      Farsund bys historie
# 25                            Byen som brant
# 26                       Bygdebok for Gaular
# 27                      Volda-soga 1800-1945
# 28                             Valle kommune
# 29                   Eidsvoll bygds historie
# ..                                       ...
# 121                                    Bærum
# 122                                1870-1989
# 123            Det arktiske Italia 1826-1920
# 124                     Stiftstad og bygdeby
# 125                Ås bygdebokverk 1850-2010
# 126                  Eidsvoll bygds historie
# 127                     Lillestrøms historie
# 128                      Rakkestads historie
# 129                 Fredrikstad bys historie
# 130                  Bygdebok for Kvam herad
# 131                        defjords historie
# 132                              Nærøyfolket
# 133                Nøtterøy inn i 1900-årene
# 134                   Småfolk og drivkrefter
# 135                    Flekkefjords historie
# 136                                 Øygarden
# 137                             Forvandlinga
# 138             Bygdehistorien fram til 1964
# 139                         Strinda bygdebok
# 140  [Den mangfoldige bygdebyen (1964-2002)]
# 141                        Heilt andre tider
# 142                                   Hvaler
# 143                                1940-1964
# 144                 Tidskifte - ny teknologi
# 145                          Nes på Romerike
# 146                      Tiden 1800 til 1980
# 147                           I krig og fred
# 148                                    Vardø
# 149                        Byen blir sentrum
# 150                       Grensebygda Neiden
#
#                                             subtittel  \
# 0
# 1                           Drøbak og Frogn 1900-1945
# 2                                           1920-1972
# 3
# 4
# 5
# 6
# 7
# 8    industrialiseringen av ei østlandsbygd 1870-1940
# 9                                       fra 1835-1985
# 10                                         1800-årene
# 11                            fra 1948 til våre dager
# 12
# 13                                          1914-1980
# 14
# 15
# 16                                        1900-tallet
# 17
# 18
# 19
# 20
# 21
# 22                   grensepost og fiskevær 1850-1950
# 23                                          1870-1972
# 24
# 25                             Kristiansund 1900-1942
# 26
# 27
# 28
# 29
# ..                                                ...
# 121                                         1840-1980
# 122
# 123
# 124                         Hamars historie 1935-1991
# 125
# 126
# 127
# 128                        bygdehistorien 1940 - 2000
# 129
# 130
# 131
# 132
# 133
# 134                           fra 1900 til 1960-årene
# 135
# 136
# 137                        Bodøs historie : 1890-1950
# 138
# 139                      med illustrasjoner og karter
# 140
# 141                                    Fusa 1900-2000
# 142                    en samtidshistorie : 1945-2000
# 143                      krig - gjenoppbygging- vekst
# 144                                         1840-1900
# 145
# 146
# 147
# 148                  grensepost og fiskevær 1850-1950
# 149                        Bodøs historie : 1816-1890
# 150  møte mellom folkegrupper og kampen om ressursene
#
#                                                utgiver     sjanger  \
# 0    Meråker kommune;[Meråker] : Meråker kommune, 1...  notfiction
# 1    Frogn kommune;[Drøbak] : Frogn kommune, 1996- ...  notfiction
# 2                 Alma mater;Bergen : Alma mater, 1995  notfiction
# 3    Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...  notfiction
# 4                   Banken;Sandane : Banken, 1978-2001  notfiction
# 5    Vigmostad &amp; Bjørke;Bergen : Alma mater, co...  notfiction
# 6            Kommunen;[Selbu] : Kommunen, 1972-[1992?]  notfiction
# 7    Nærøy kommune;Kolvereid : Nærøy kommune, 2000-...  notfiction
# 8                                        Modum kommune  notfiction
# 9          Sogelaget;[Aurland] : Sogelaget, 1962-    .  notfiction
# 10                                    Nøtterøy kommune
# 11               Cappelen;[Oslo] : Cappelen, 1990-1994     unknown
# 12        Nes kommune;[Årnes] : Nes kommune, 1996-1998  notfiction
# 13   Gausdal kommune;[Gausdal] : Gausdal kommune, 1...  notfiction
# 14         Kommunen;Fredrikstad : Kommunen, 1960-    .     fiction
# 15                                       Bykle kommune  notfiction
# 16   Nøtterøy kommune;[Borgheim] : Nøtterøy kommune...  notfiction
# 17                                     Rolvsøy kommune  notfiction
# 18     Volda kommune;Volda : Volda kommune, 1996-2004.  notfiction
# 19                                Sør-Varanger kommune  notfiction
# 20   Hobøl kommune;[Hobøl] : Hobøl kommune, 1993-1995.  notfiction
# 21   Nore og Uvdal kommune;[Nore] : Nore og Uvdal k...  notfiction
# 22   Vardø kommune ; Stavanger : Dreyer Bok;Vardø :...  notfiction
# 23   Fana bygdebokmemnd;Bergen : Fana bygdebokmemnd...  notfiction
# 24   Farsund kommune;[Farsund] : Farsund kommune, 1...  notfiction
# 25   I kommisjon hos Barmans bokhandel;Kristiansund...  notfiction
# 26   [Gaular sogenemnd];[Høyanger] : [Gaular sogene...  notfiction
# 27     Volda kommune;Volda : Volda kommune, 1996-2004.  notfiction
# 28           Valle kommune;Valle : Valle kommune, 1994  notfiction
# 29   Eidsvoll kommune;[Eidsvoll] : Eidsvoll kommune...  notfiction
# ..                                                 ...         ...
# 121  Universitetsforl.;Oslo : Universitetsforl., 19...  notfiction
# 122  Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...     fiction
# 123      Alta kommune;[Alta] : Alta kommune, 1990-2003  notfiction
# 124                                      Hamar kommune  notfiction
# 125              Ås kommune;Ås : Ås kommune, 2007-2012  notfiction
# 126  Eidsvoll kommune;[Eidsvoll] : Eidsvoll kommune...  notfiction
# 127                  Kommunen;Skedsmo : Kommunen, 1978  notfiction
# 128         Kommunen;[Rakkestad] : Kommunen, 1989-2002  notfiction
# 129        Kommunen;Fredrikstad : Kommunen, 1960-    .  notfiction
# 130         Kvam herad;Norheimsund : Kvam herad, 1999-  notfiction
# 131  Sandefjord kommune;[Sandefjord] : Sandefjord k...  notfiction
# 132  Nærøy kommune;Kolvereid : Nærøy kommune, 2000-...  notfiction
# 133                                   Nøtterøy kommune  notfiction
# 134  Porsanger kommune;[Lakselv] : Porsanger kommun...  notfiction
# 135  [Flekkefjord sparebank];Flekkefjord : [Flekkef...  notfiction
# 136  Øygarden kommune;Tjeldstø : Øygarden kommune, ...  notfiction
# 137  Tapir akademisk forl.;Trondheim : Tapir akadem...  notfiction
# 138         Kommunen;[Eidsvoll] : Kommunen, 1983-1986.  notfiction
# 139  I kommisjon hos F. Bruns bokhandels forlag;[Tr...  notfiction
# 140      Alta kommune;[Alta] : Alta kommune, 1990-2003  notfiction
# 141  Fusa kommune;Eikelandsosen : Fusa kommune, 200...  notfiction
# 142                                          Aschehoug  notfiction
# 143   Molde kommune;[Molde] : Molde kommune, 1962-1994  notfiction
# 144  Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 145             Kommunen;[Årnes] : Kommunen, 1958-1980     unknown
# 146  Rygge sparebank;[Rygge] : Rygge sparebank, 195...  notfiction
# 147  Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 148  Vardø kommune ; Stavanger : Dreyer Bok;Vardø :...  notfiction
# 149  Tapir akademisk forl.;Trondheim : Tapir akadem...  notfiction
# 150        Nordkalott-forl.;Sør-Varanger museums forl.  notfiction
#
#                               sesamid språk oversatt fra
# 0    c63396a71fe847a243ae6725655c136f   nob
# 1    83f49b7346eeec34a2d4b54aadbf44c9   nob
# 2    7d96702b85f883f62f1d6c155cff13cb   nob
# 3    cf0de84772e5e12c81790a2d47136b12   nno
# 4    8add46a3b09d65e742ea8c51ee59e030   und
# 5    50e0145f08949e95d8d0528d4c106735   nno
# 6    1557b0b1b118195f94a881a2a9531280   nob
# 7    84bdba425bb50e9368ce5fb754b1bc49   nob
# 8    4727a4119503e3e9869dd2bb1763dc28   nob
# 9    04b078dc51ec9a23bc8fcbe59de78e71   nno
# 10   4f3fd9434f6e99aff9de87164fe05ef8   nob
# 11   ef6e037482a38600e47de3502b4836ef   nob
# 12   89d167b178af44ead0427fbf0a2208f4   nob
# 13   02d799822ad7f964e4c6c2555680d4c9   nob
# 14   70846771325578004627165b54892b5e   nob
# 15   5d6354a52f3e8025ca78559eef78fe63   mul
# 16   589b7592e2770ccffc20344f542b5512   nob
# 17   8f07cc0e6402cb309ec6eb851523130d   nob
# 18   9aa139a2ffec95faee8de4fa6b0a8a26   nno
# 19   0aee8ab0124bf9a6ecc11d855e5c61e6   nob
# 20   a4c2dc4e762e42472be45edc7f21544f   nob
# 21   76cd800e22060c2b21c51dbbef099f07   nno
# 22   f44018a116994a564221759c3deaee5d   nob
# 23   656b9ae5f3b262c79ec7a8e69e4513db   nno
# 24   a75ed2ef371df6c1dc794cae4801a681   nob
# 25   d5a63a5e0078b1adfbab96efda592ade   nob
# 26   016b5611f5d2cb5a29709b97a8d1f320   nno
# 27   e2775ffb9328b7048703ccc123d707c4   nno
# 28   6ae39505d2f048de59b66e3e31d6617f   nno
# 29   cd6797e4879223d24f3e919262a6c962   nob
# ..                                ...   ...          ...
# 121  652eb1c7487f24c4d0f4f0b940c0fa32   nob
# 122  9917f589d103511b39892997d943818a   nno
# 123  e8109d3dffca95bfeea7bd479157814c   nob
# 124  fc74f628f29fddeda3dc39e38d47bced   nob
# 125  ed2bc99cee7727f46d0fa84818f88688   nob
# 126  dbad044c10e1ad004e4af0dbcdf21fb4   nob
# 127  d112a1c287bdae8becce80d50e6bc1f1   und
# 128  54915e7105c0d8e5973aa5197792012d   nob
# 129  a58ff37a87ba85d0d480099cf6837bc3   nob
# 130  3e12a2c9982d5a0ecd9fb215e5793a0f   nno
# 131  2b2f18cb30b245bbf6437489d6c9adf1   nob
# 132  d29b7bf45a8cca1b45ff48a0a76eecc8   nob
# 133  4c4ada0aef8549a56789fa57a21898ec   nob
# 134  6f5be2a39a81b848383c0129e0c11a04   nob
# 135  e7c1e7c791d9cce2bf4c7c641216f274   nob
# 136  f4c788dafc1c4f131823c13874e49141   nno
# 137  e8dac3ff9786d589d393bd2a4601012f   nob
# 138  4e0fb6b9aea04eb74017a0d747488d44   nob
# 139  5362abf7e800258c8e75b8d15d83626f   nob
# 140  2cdbf8dd8ab9c3525cd626eec7d6c680   nob
# 141  6b0ae5e01425252ab3ab16df9c79a12a   nno
# 142  5c02e8dcc5d77557fdcca6e0eb7d7a0e   nob
# 143  7481a95c1bc2b9b1eb3528ab997687da   nob
# 144  037081fcfdb530ee8281bb35c0ca39cf   nob
# 145  a575b29c4b8118e46cb3f607bc44900a   nob
# 146  15b1fe96ecc3363d3ecde2c553f1a66e   nob
# 147  4645ef6289d180cd15fc055a6333262d   nob
# 148  b3812dd7c4eac6c73efd71c7b542de69   nob
# 149  ca5008b28c0f691553c0859bd6e52495   nob
# 150  1867ff2598772dae88f8b37ac8f224bd   nob
#
# [151 rows x 10 columns]

# %% [markdown]
# ### Finne frem til bøker
#
# Bruk **urnlist** for å referere til en bok. Cellen under gir et idiom for å finne frem bøker basert på forfatter. Det er mulig å lage kortkommandoer som gjør ting litt enklere, bare si fra hvordan dere vil det skal være. Hvis det er greit som det vises i cellen under, går det fint. Bare bytt ut forfatternavnet med et annet.

# %%
forfatter = lambda x: urnlist[urnlist['forfatter'].str.contains(x)]
tittel = lambda x: urnlist[urnlist['tittel'].str.contains(x)]

# %%
forfatter('Alsvik')
# Out:
#                urn    forfatter    år                  tittel  \
# 3    2013091708048  Alsvik, Jan  1989               1800-1870
# 72   2015090348036  Alsvik, Ola  2006            Storkommunen
# 118  2011031103008  Alsvik, Ola  1998  Historien om Lørenskog
# 147  2013062406124  Alsvik, Ola  2001          I krig og fred
#
#                             subtittel  \
# 3
# 72                          Ringsaker
# 118  myter og mennesker 1900 til 1990
# 147
#
#                                                utgiver     sjanger  \
# 3    Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...  notfiction
# 72   Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 118                                  Lørenskog kommune  notfiction
# 147  Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
#
#                               sesamid språk oversatt fra
# 3    cf0de84772e5e12c81790a2d47136b12   nno
# 72   5821efc1f73613aa430f9afffe0ba91a   nob
# 118  cf40aed1e3931494f12d43af05c81034   nob
# 147  4645ef6289d180cd15fc055a6333262d   nob

# %%
tittel('kommune')
# Out:
#                urn            forfatter    år            tittel  subtittel  \
# 28   2015072308166  Jansen, Leonhard B.  1994     Valle kommune
# 72   2015090348036          Alsvik, Ola  2006      Storkommunen  Ringsaker
# 76   2013062038075         Evjen, Bjørg  1998     fjord kommune
# 119  2013061938074         Evjen, Bjørg  2001  Tysfjord kommune
#
#                                                utgiver     sjanger  \
# 28           Valle kommune;Valle : Valle kommune, 1994  notfiction
# 72   Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 76           Kommunen;[Kjøpsvik] : Kommunen, 1998-2001  notfiction
# 119          Kommunen;[Kjøpsvik] : Kommunen, 1998-2001  notfiction
#
#                               sesamid språk oversatt fra
# 28   6ae39505d2f048de59b66e3e31d6617f   nno
# 72   5821efc1f73613aa430f9afffe0ba91a   nob
# 76   1638f31cc74a4fd790b1b9f3e853f2c1   nob
# 119  3d3815ff4b6642174b44e1f3fff493be   nob

# %%
urnlist[urnlist['forfatter'].str.contains('Alsvi')]
# Out:
#                urn    forfatter    år                  tittel  \
# 3    2013091708048  Alsvik, Jan  1989               1800-1870
# 72   2015090348036  Alsvik, Ola  2006            Storkommunen
# 118  2011031103008  Alsvik, Ola  1998  Historien om Lørenskog
# 147  2013062406124  Alsvik, Ola  2001          I krig og fred
#
#                             subtittel  \
# 3
# 72                          Ringsaker
# 118  myter og mennesker 1900 til 1990
# 147
#
#                                                utgiver     sjanger  \
# 3    Gjesdal kommune;[Ålgård] : Gjesdal kommune, 19...  notfiction
# 72   Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
# 118                                  Lørenskog kommune  notfiction
# 147  Brøttum historielag;[Brumunddal] : Brøttum his...  notfiction
#
#                               sesamid språk oversatt fra
# 3    cf0de84772e5e12c81790a2d47136b12   nno
# 72   5821efc1f73613aa430f9afffe0ba91a   nob
# 118  cf40aed1e3931494f12d43af05c81034   nob
# 147  4645ef6289d180cd15fc055a6333262d   nob

# %% [markdown]
# ### Sett av ord for å sjekke mot.
#
# Lag en liste av ord for å se utviklingen, listen kan være enkeltord er flere ord. Definer dem som i mønsteret nedenfor, og sett variabelen inn i kommandoen for vekstdiagrammet.

# %%
traktor = """traktor, Traktor, traktoren, Traktoren""".split(', ')

# %%
gårdsord = """låve, Låve, Låven, låven, fjøs, fjøsen, fjøset, Fjøsen, Fjøset""".split(', ')

# %%
kvinneord = """kvinnfolk, kvinnfolka, kvinnfolket, kvinner, jenter, jenta, jenten, datter, dattera, kone, konen""".split(', ')

# %% [markdown]
# ## Lag buer for ordene i en bestemt bok
#
# Finn URN-en som i ovenfor, klipp ut selve URN-referansen og lim inn den inn i kommandoen under. Kopier cellen og lim inn så mange kopier det trengs.

# %%
sammenlign = lambda x, y, z: (plot(x , z, window=5000, pr=100),
plot(y ,z, window=5000, pr=100))

# %%
tallord = ['hundre', 'tusen', 'tjue','tyve','tredve']

# %%
nb.plot_sammen_vekst??

# %%
nb.plot_book_wordbags(2018032348039 , {'Q': kvinneord, 'Tallord':tallord, 'Helse':['helse', 'sykdom','sanitetsforeningen']}, window=4000, pr=100)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-26-bd553a08929e> in <module>
# ----> 1 nb.plot_book_wordbags(2018032348039 , {'Q': kvinneord, 'Tallord':tallord, 'Helse':['helse', 'sykdom','sanitetsforeningen']}, window=4000, pr=100)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in plot_book_wordbags(urn, wordbags, window, pr)
#    1280 def plot_book_wordbags(urn, wordbags, window=5000, pr = 100):
#    1281     """Generate a diagram of wordbags in book """
# -> 1282     return plot_sammen_vekst(urn, wordbags, window=window, pr=pr)
#    1283
#    1284
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in plot_sammen_vekst(urn, ordlister, window, pr)
#    1297         c = ordlister
#    1298     for key in c:
# -> 1299         vekst = vekstdiagram(urn, params = {'words': c[key], 'window':window, 'pr': pr} )
#    1300         vekst.columns = [key]
#    1301         rammer.append(vekst)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in vekstdiagram(urn, params)
#    1276     para['urn']= urn
#    1277     r = requests.post('https://api.nb.no/ngram/vekstdiagram', json = para)
# -> 1278     return pd.DataFrame(r.json())
#    1279
#    1280 def plot_book_wordbags(urn, wordbags, window=5000, pr = 100):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
sammenlign(2013062038075, 2018032348039 , {'Q': kvinneord, 'Tallord':tallord, 'Helse':['helse', 'sykdom','sanitetsforeningen']})
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-60356c1d7534> in <module>
# ----> 1 sammenlign(2013062038075, 2018032348039 , {'Q': kvinneord, 'Tallord':tallord, 'Helse':['helse', 'sykdom','sanitetsforeningen']})
#
# <ipython-input-20-b847b457ce61> in <lambda>(x, y, z)
#       1 sammenlign = lambda x, y, z: (plot(x , z, window=5000, pr=100),
# ----> 2 plot(y ,z, window=5000, pr=100))
#
# <ipython-input-24-c84750e2da8e> in plot(urn, wordbag, window, pr, lw, alpha)
#       5         md = ['x','y','z','u']
#       6     #print(md)
# ----> 7     x = nb.plot_book_wordbags(urn , wordbag, window=window, pr=pr)
#       8     x.plot(figsize=(12, 5), lw=lw, alpha=alpha, title=', '.join([str(m) for m in md]))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in plot_book_wordbags(urn, wordbags, window, pr)
#    1280 def plot_book_wordbags(urn, wordbags, window=5000, pr = 100):
#    1281     """Generate a diagram of wordbags in book """
# -> 1282     return plot_sammen_vekst(urn, wordbags, window=window, pr=pr)
#    1283
#    1284
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in plot_sammen_vekst(urn, ordlister, window, pr)
#    1297         c = ordlister
#    1298     for key in c:
# -> 1299         vekst = vekstdiagram(urn, params = {'words': c[key], 'window':window, 'pr': pr} )
#    1300         vekst.columns = [key]
#    1301         rammer.append(vekst)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\dhlab\nbtext.py in vekstdiagram(urn, params)
#    1276     para['urn']= urn
#    1277     r = requests.post('https://api.nb.no/ngram/vekstdiagram', json = para)
# -> 1278     return pd.DataFrame(r.json())
#    1279
#    1280 def plot_book_wordbags(urn, wordbags, window=5000, pr = 100):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
